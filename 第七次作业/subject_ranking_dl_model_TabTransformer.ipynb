# %% [markdown]
# # TabTransformer 大学排名预测模型
#
# ## 模型说明
# 本实验使用 **TabTransformer** 架构优化第六次作业的 Baseline MLP 方案。

# %%
"""
实验要求1：利用TabTransformer深度学习方法,对各学科做一个排名模型,
能够较好的预测出排名位置,并且利用MSE、MAPE等指标来进行评价模型的优劣。
"""

import os
import math
import mysql.connector
from mysql.connector import Error
import numpy as np
import pandas as pd
from scipy.stats import spearmanr, rankdata
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from matplotlib import rcParams
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import warnings
import traceback

# ============================================================================
# ⚙️ 配置与初始化
# ============================================================================
warnings.filterwarnings('ignore')
rcParams['font.sans-serif'] = ['SimHei']
rcParams['axes.unicode_minus'] = False

# ============================================================================
# 🎛️ 超参数配置区域
# ============================================================================
class HyperParameters:
    """集中管理所有超参数"""
    DB_CONFIG = {
        'host': os.getenv('MYSQL_HOST', 'localhost'),
        'user': os.getenv('MYSQL_USER', 'root'),
        'password': os.getenv('MYSQL_PASSWORD', 'zzy419220'),
        'database': os.getenv('MYSQL_DB', 'university_ranking')
    }
    FEATURES = ['web_of_science_documents', 'cites', 'cites_per_paper', 'top_papers']
    TARGET = 'ranking_position'
    MIN_SAMPLES_PER_FIELD = 15
    OUTLIER_QUANTILE_LOW = 0.05
    OUTLIER_QUANTILE_HIGH = 0.95
    TEST_SIZE = 0.2
    VAL_SIZE = 0.2
    RANDOM_STATE = 42
    
    # TabTransformer 专用参数
    D_MODEL = 64              # Transformer 隐藏层维度
    NHEAD = 4                 # 注意力头数
    NUM_TRANSFORMER_LAYERS = 3  # Transformer 层数
    DIM_FEEDFORWARD = 256     # FeedForward 层维度
    TRANSFORMER_DROPOUT = 0.1  # Transformer Dropout
    
    DROPOUT_RATE = 0.1
    BATCH_SIZE = 32
    EPOCHS = 200
    LEARNING_RATE = 0.001
    WEIGHT_DECAY = 1e-4
    OPTIMIZER = 'adamw'
    LR_SCHEDULER = 'plateau'
    LR_PATIENCE = 10
    LR_FACTOR = 0.5
    EARLY_STOP_PATIENCE = 20
    EARLY_STOP_MIN_DELTA = 0.001
    NORMALIZE_METRICS = True
    METRIC_NORM_METHOD = 'minmax'
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    USE_AMP = torch.cuda.is_available()
    NUM_WORKERS = 0
    PIN_MEMORY = torch.cuda.is_available()

HP = HyperParameters()

# ============================================================================
# 🧠 TabTransformer 模型定义
# ============================================================================
class TabTransformer(nn.Module):
    """
    TabTransformer: Transformer架构用于表格数据
    
    核心思想:
    1. 每个特征独立嵌入到高维空间
    2. 添加[CLS] token用于聚合信息
    3. 使用Transformer编码器捕捉特征交互
    4. 从[CLS] token提取最终表示用于预测
    """
    def __init__(self, num_features, d_model=64, nhead=4, num_layers=3, dim_feedforward=256, dropout=0.1):
        super(TabTransformer, self).__init__()
        self.num_features = num_features
        self.d_model = d_model
        
        # 1. 特征嵌入层 (每个特征独立映射到d_model维)
        self.feature_embedding = nn.Linear(1, d_model)
        
        # 2. [CLS] token (用于聚合所有特征信息)
        self.cls_token = nn.Parameter(torch.randn(1, 1, d_model))
        
        # 3. Transformer编码器
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            activation='gelu',  # 使用GELU激活函数
            batch_first=False   # [seq_len, batch, d_model]
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer, 
            num_layers=num_layers
        )
        
        # 4. 输出头 (MLP)
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model // 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, 1)
        )
        
        self._init_weights()
    
    def _init_weights(self):
        """初始化权重"""
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
    
    def forward(self, x):
        """
        前向传播
        Args:
            x: [batch_size, num_features] 输入特征
        Returns:
            [batch_size] 预测值
        """
        batch_size = x.size(0)
        
        # 1. 特征嵌入: [B, num_features] -> [B, num_features, 1] -> [B, num_features, d_model]
        x = x.unsqueeze(-1)  # [B, num_features, 1]
        feature_embeddings = self.feature_embedding(x)  # [B, num_features, d_model]
        
        # 2. 添加[CLS] token: [B, 1, d_model]
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)  # [B, 1, d_model]
        
        # 3. 拼接: [B, num_features+1, d_model]
        embeddings = torch.cat([cls_tokens, feature_embeddings], dim=1)
        
        # 4. 转置为Transformer输入格式: [num_features+1, B, d_model]
        embeddings = embeddings.transpose(0, 1)
        
        # 5. Transformer编码
        transformer_output = self.transformer_encoder(embeddings)  # [num_features+1, B, d_model]
        
        # 6. 提取[CLS] token的输出: [B, d_model]
        cls_output = transformer_output[0]  # 第一个位置是[CLS]
        
        # 7. 通过输出头得到预测: [B, 1] -> [B]
        output = self.output_head(cls_output).squeeze(-1)
        
        return output

# ============================================================================
# 🔧 辅助类定义
# ============================================================================
class EarlyStopping:
    """早停机制"""
    def __init__(self):
        self.patience = HP.EARLY_STOP_PATIENCE
        self.min_delta = HP.EARLY_STOP_MIN_DELTA
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

class MetricsNormalizer:
    """评估指标正则化器"""
    def __init__(self):
        self.scalers = {}
        self.fitted = False

    def fit(self, metrics_dict):
        if not metrics_dict: return
        all_metrics = {}
        for field_metrics in metrics_dict.values():
            for name, value in field_metrics.items():
                if name not in all_metrics: all_metrics[name] = []
                all_metrics[name].append(value)
        for name, values in all_metrics.items():
            scaler = MinMaxScaler() if HP.METRIC_NORM_METHOD == 'minmax' else StandardScaler()
            scaler.fit(np.array(values).reshape(-1, 1))
            self.scalers[name] = scaler
        self.fitted = True

    def transform(self, metrics):
        if not self.fitted or not HP.NORMALIZE_METRICS: return metrics
        normalized = {}
        for name, value in metrics.items():
            if name in self.scalers:
                normalized[name] = self.scalers[name].transform([[value]])[0][0]
            else:
                normalized[name] = value
        return normalized

    def get_composite_score(self, metrics):
        if not self.fitted or not HP.NORMALIZE_METRICS: return metrics.get('R2', 0)
        weights = {'MAE': -0.15, 'MSE': -0.15, 'RMSE': -0.15, 'R2': 0.30, 'MAPE': -0.15, 'Spearman': 0.10}
        score = 0
        for name, weight in weights.items():
            if name in metrics:
                norm_val = metrics[name]
                score += abs(weight) * (1 - norm_val) if weight < 0 else weight * norm_val
        return score

# ============================================================================
# 🚀 主控制器
# ============================================================================
class TabTransformerPredictor:
    def __init__(self):
        self.results = {}
        self.metrics_normalizer = MetricsNormalizer()

    def plot_training_history(self, field_name, train_losses, val_losses, output_dir='hw7result-TabTransformer/plots'):
        """绘制训练过程的损失曲线"""
        os.makedirs(output_dir, exist_ok=True)

        plt.figure(figsize=(12, 6))
        epochs = range(1, len(train_losses) + 1)

        plt.plot(epochs, train_losses, 'b-', label='训练损失', linewidth=2)
        plt.plot(epochs, val_losses, 'orange', label='验证损失', linewidth=2)

        plt.title(f'{field_name} - TabTransformer 训练过程', fontsize=16, fontweight='bold')
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Loss (MSE)', fontsize=12)
        plt.legend(fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()

        # 保存图片
        safe_filename = field_name.replace('/', '_').replace('\\', '_').replace(' ', '_')
        save_path = os.path.join(output_dir, f'{safe_filename}_tabtransformer_training.png')
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        plt.close()

        return save_path

    def load_data(self):
        print("=" * 80 + "\n📥 正在连接数据库并加载数据...")
        try:
            conn = mysql.connector.connect(**HP.DB_CONFIG)
            query = "SELECT * FROM university_rankings WHERE ranking_position IS NOT NULL"
            df = pd.read_sql(query, conn)
            conn.close()
            print(f"✅ 数据加载成功: {len(df):,} 条记录, {df['subject_field'].nunique()} 个学科")
            return df
        except mysql.connector.Error as err:
            print(f"❌ 数据库连接错误: {err}")
            return None

    def preprocess(self, df):
        print("=" * 80 + "\n🔧 数据预处理中...")
        for col in HP.FEATURES + [HP.TARGET]:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        for col in HP.FEATURES:
            q_low, q_high = df[col].quantile([HP.OUTLIER_QUANTILE_LOW, HP.OUTLIER_QUANTILE_HIGH])
            df[col] = np.clip(df[col], q_low, q_high)
        original_fields = df['subject_field'].nunique()
        field_counts = df['subject_field'].value_counts()
        valid_fields = field_counts[field_counts >= HP.MIN_SAMPLES_PER_FIELD].index
        df = df[df['subject_field'].isin(valid_fields)]
        print(f"✅ 预处理完成: 保留 {len(valid_fields)}/{original_fields} 个学科")
        return df

    def calculate_metrics(self, y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return {
            'MAE': mean_absolute_error(y_true, y_pred),
            'MSE': mean_squared_error(y_true, y_pred),
            'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
            'R2': r2_score(y_true, y_pred),
            'MAPE': np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100,
            'Spearman': spearmanr(rankdata(y_true), rankdata(y_pred))[0]
        }

    def train_single_model(self, X_train, y_train, X_val, y_val):
        """训练单个TabTransformer模型"""
        train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train.values))
        train_loader = DataLoader(
            train_dataset, 
            batch_size=HP.BATCH_SIZE, 
            shuffle=True, 
            num_workers=HP.NUM_WORKERS, 
            pin_memory=HP.PIN_MEMORY, 
            drop_last=True  # 避免最后一个batch只有1个样本
        )
        X_val_tensor = torch.FloatTensor(X_val).to(HP.DEVICE)
        y_val_tensor = torch.FloatTensor(y_val.values).to(HP.DEVICE)

        # 初始化TabTransformer模型
        model = TabTransformer(
            num_features=X_train.shape[1],
            d_model=HP.D_MODEL,
            nhead=HP.NHEAD,
            num_layers=HP.NUM_TRANSFORMER_LAYERS,
            dim_feedforward=HP.DIM_FEEDFORWARD,
            dropout=HP.TRANSFORMER_DROPOUT
        ).to(HP.DEVICE)
        
        criterion = nn.MSELoss()
        optimizer = optim.AdamW(model.parameters(), lr=HP.LEARNING_RATE, weight_decay=HP.WEIGHT_DECAY)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, 'min', 
            factor=HP.LR_FACTOR, 
            patience=HP.LR_PATIENCE
        )
        scaler = torch.cuda.amp.GradScaler(enabled=HP.USE_AMP)
        early_stopping = EarlyStopping()

        best_val_loss = float('inf')
        best_model_state = None
        train_losses = []
        val_losses = []

        for epoch in range(HP.EPOCHS):
            # 训练阶段
            model.train()
            epoch_train_loss = 0
            batch_count = 0
            
            for batch_X, batch_y in train_loader:
                batch_X, batch_y = batch_X.to(HP.DEVICE), batch_y.to(HP.DEVICE)
                optimizer.zero_grad()
                
                with torch.cuda.amp.autocast(enabled=HP.USE_AMP):
                    outputs = model(batch_X)
                    loss = criterion(outputs, batch_y)
                
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                
                epoch_train_loss += loss.item()
                batch_count += 1

            avg_train_loss = epoch_train_loss / batch_count if batch_count > 0 else 0
            train_losses.append(avg_train_loss)

            # 验证阶段
            model.eval()
            with torch.no_grad():
                with torch.cuda.amp.autocast(enabled=HP.USE_AMP):
                    val_loss = criterion(model(X_val_tensor), y_val_tensor).item()

            val_losses.append(val_loss)
            scheduler.step(val_loss)
            
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict().copy()

            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"  ⏹️ 提前停止于第 {epoch+1} 轮, 最佳验证损失: {best_val_loss:.4f}")
                break

        model.load_state_dict(best_model_state)
        if torch.cuda.is_available(): 
            torch.cuda.empty_cache()
        
        return model, train_losses, val_losses

    def train_all_models(self, df):
        print("=" * 80 + "\n🚀 开始使用TabTransformer训练所有模型...")
        fields = df['subject_field'].unique()
        all_raw_metrics = {}

        for i, field in enumerate(fields, 1):
            print(f"\n{'─' * 80}\n🔬 [{i:2d}/{len(fields)}] 训练学科: {field}")
            df_field = df[df['subject_field'] == field]
            X, y = df_field[HP.FEATURES], df_field[HP.TARGET]

            imputer = SimpleImputer(strategy='median')
            X_imputed = imputer.fit_transform(X)
            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X_imputed)

            X_temp, X_test, y_temp, y_test = train_test_split(
                X_scaled, y, test_size=HP.TEST_SIZE, random_state=HP.RANDOM_STATE
            )
            val_size_adj = HP.VAL_SIZE / (1 - HP.TEST_SIZE)
            X_train, X_val, y_train, y_val = train_test_split(
                X_temp, y_temp, test_size=val_size_adj, random_state=HP.RANDOM_STATE
            )

            print(f"  📊 数据划分: 训练={len(X_train)} | 验证={len(X_val)} | 测试={len(X_test)}")

            try:
                model, train_losses, val_losses = self.train_single_model(X_train, y_train, X_val, y_val)
                
                # 测试集评估
                model.eval()
                with torch.no_grad():
                    y_pred = model(torch.FloatTensor(X_test).to(HP.DEVICE)).cpu().numpy()

                metrics = self.calculate_metrics(y_test, y_pred)
                all_raw_metrics[field] = metrics

                # 绘制训练过程图
                plot_path = self.plot_training_history(field, train_losses, val_losses)

                self.results[field] = {
                    'model': model, 
                    'scaler': scaler, 
                    'imputer': imputer, 
                    'raw_metrics': metrics,
                    'sizes': (len(X_train), len(X_val), len(X_test)),
                    'plot_path': plot_path,
                    'train_losses': train_losses,
                    'val_losses': val_losses
                }

                status = "🟢" if metrics['R2'] > 0.5 else "🟡" if metrics['R2'] > 0 else "🔴"
                print(f"  {status} 训练完成: R²={metrics['R2']:.4f}, MAE={metrics['MAE']:.2f}, MAPE={metrics['MAPE']:.2f}%")
                print(f"  📊 训练过程图已保存: {plot_path}")
                
            except Exception as e:
                print(f"  ❌ 训练失败: {str(e)}")
                print(f"  详细错误: {traceback.format_exc()}")

        # 指标归一化
        if HP.NORMALIZE_METRICS and all_raw_metrics:
            print("=" * 80 + "\n📐 正在对评估指标进行归一化...")
            self.metrics_normalizer.fit(all_raw_metrics)
            for field, data in self.results.items():
                norm_metrics = self.metrics_normalizer.transform(data['raw_metrics'])
                data['normalized_metrics'] = norm_metrics
                data['composite_score'] = self.metrics_normalizer.get_composite_score(norm_metrics)
            print("✅ 指标归一化完成")

    def report_and_save(self, output_dir='hw7result-TabTransformer'):
        """生成报告并保存结果"""
        if not self.results:
            print("❌ 没有可用的训练结果")
            return
        
        os.makedirs(output_dir, exist_ok=True)
        print("=" * 80 + "\n📈 TabTransformer 模型性能摘要报告\n" + "=" * 80)
        
        sort_key = 'composite_score' if HP.NORMALIZE_METRICS else 'R2'
        reverse_sort = True
        
        # 确保所有结果都有composite_score
        for field, data in self.results.items():
            if 'composite_score' not in data:
                data['composite_score'] = data['raw_metrics'].get('R2', 0)

        sorted_results = sorted(
            self.results.items(), 
            key=lambda x: x[1].get(sort_key, 0), 
            reverse=reverse_sort
        )

        print(f"\n🏆 表现最佳的前5个学科 (按 {sort_key} 排序):")
        print("=" * 80)
        for rank, (field, data) in enumerate(sorted_results[:5], 1):
            m = data['raw_metrics']
            score_info = f"| 综合评分: {data['composite_score']:.4f}" if HP.NORMALIZE_METRICS else ""
            print(f"{rank}. {field:<35} | R²: {m['R2']:.4f} | MAE: {m['MAE']:.2f} {score_info}")

        print(f"\n⚠️ 需要改进的后5个学科 (按 {sort_key} 排序):")
        print("=" * 80)
        for rank, (field, data) in enumerate(sorted_results[-5:], 1):
            m = data['raw_metrics']
            score_info = f"| 综合评分: {data['composite_score']:.4f}" if HP.NORMALIZE_METRICS else ""
            print(f"{rank}. {field:<35} | R²: {m['R2']:.4f} | MAE: {m['MAE']:.2f} {score_info}")

        # 保存CSV
        results_data = []
        for field, data in self.results.items():
            row = {
                'subject_field': field, 
                'train_size': data['sizes'][0], 
                'val_size': data['sizes'][1], 
                'test_size': data['sizes'][2]
            }
            row.update({k: round(v, 4) for k, v in data['raw_metrics'].items()})
            if HP.NORMALIZE_METRICS:
                row['composite_score'] = round(data['composite_score'], 4)
            results_data.append(row)
        
        df_results = pd.DataFrame(results_data).sort_values(sort_key, ascending=not reverse_sort)
        csv_path = os.path.join(output_dir, 'tabtransformer_metrics.csv')
        df_results.to_csv(csv_path, index=False, encoding='utf-8-sig')
        print(f"\n💾 结果已保存到: {csv_path}")
        
        return df_results

# ============================================================================
# 🚀 主执行函数
# ============================================================================
def main():
    print("🎯" * 20 + " TabTransformer 排名预测系统 " + "🎯" * 20)
    print(f"🖥️ 使用设备: {HP.DEVICE}{' (⚡已启用混合精度)' if HP.USE_AMP else ''}")
    print(f"🔧 模型配置: d_model={HP.D_MODEL}, nhead={HP.NHEAD}, layers={HP.NUM_TRANSFORMER_LAYERS}")
    
    predictor = TabTransformerPredictor()
    df = predictor.load_data()
    if df is None: 
        return
    
    df_processed = predictor.preprocess(df)
    if df_processed is None or df_processed.empty:
        print("❌ 预处理后无有效数据，程序终止。")
        return
        
    predictor.train_all_models(df_processed)
    results_df = predictor.report_and_save()
    
    print("\n" + "✅" * 20 + " TabTransformer 训练完毕 " + "✅" * 20)
    
    return predictor, results_df

if __name__ == "__main__":
    predictor, results = main()
# Out:
# 🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯 TabTransformer 排名预测系统 🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯🎯
# 🖥️ 使用设备: cuda (⚡已启用混合精度)
# 🔧 模型配置: d_model=64, nhead=4, layers=3
# ================================================================================
# 📥 正在连接数据库并加载数据...
# ✅ 数据加载成功: 34,121 条记录, 22 个学科
# ================================================================================
# 🔧 数据预处理中...
# ✅ 预处理完成: 保留 22/22 个学科
# ================================================================================
# 🚀 开始使用TabTransformer训练所有模型...
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 1/22] 训练学科: AGRICULTURAL SCIENCES
#   📊 数据划分: 训练=828 | 验证=276 | 测试=277
#   ⏹️ 提前停止于第 193 轮, 最佳验证损失: 5570.5913
#   🟢 训练完成: R²=0.9430, MAE=55.01, MAPE=11.49%
#   📊 训练过程图已保存: hw7result/plots\AGRICULTURAL_SCIENCES_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 2/22] 训练学科: BIOLOGY & BIOCHEMISTRY
#   📊 数据划分: 训练=989 | 验证=330 | 测试=330
#   ⏹️ 提前停止于第 138 轮, 最佳验证损失: 7253.8682
#   🟢 训练完成: R²=0.9735, MAE=61.86, MAPE=13.48%
#   📊 训练过程图已保存: hw7result/plots\BIOLOGY_&_BIOCHEMISTRY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 3/22] 训练学科: CHEMISTRY
#   📊 数据划分: 训练=1284 | 验证=428 | 测试=429
#   ⏹️ 提前停止于第 102 轮, 最佳验证损失: 9485.0410
#   🟢 训练完成: R²=0.9783, MAE=66.83, MAPE=11.68%
#   📊 训练过程图已保存: hw7result/plots\CHEMISTRY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 4/22] 训练学科: CLINICAL MEDICINE
#   📊 数据划分: 训练=4052 | 验证=1351 | 测试=1351
#   ⏹️ 提前停止于第 143 轮, 最佳验证损失: 98126.5234
#   🟢 训练完成: R²=0.9673, MAE=222.21, MAPE=14.46%
#   📊 训练过程图已保存: hw7result/plots\CLINICAL_MEDICINE_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 5/22] 训练学科: COMPUTER SCIENCE
#   📊 数据划分: 训练=517 | 验证=173 | 测试=173
#   ⏹️ 提前停止于第 83 轮, 最佳验证损失: 3292.1892
#   🟢 训练完成: R²=0.9368, MAE=45.83, MAPE=16.57%
#   📊 训练过程图已保存: hw7result/plots\COMPUTER_SCIENCE_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 6/22] 训练学科: ECONOMICS & BUSINESS
#   📊 数据划分: 训练=325 | 验证=109 | 测试=109
#   ⏹️ 提前停止于第 80 轮, 最佳验证损失: 1476.0865
#   🟢 训练完成: R²=0.9491, MAE=27.57, MAPE=24.40%
#   📊 训练过程图已保存: hw7result/plots\ECONOMICS_&_BUSINESS_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 7/22] 训练学科: ENGINEERING
#   📊 数据划分: 训练=1671 | 验证=558 | 测试=558
#   ⏹️ 提前停止于第 130 轮, 最佳验证损失: 28496.9844
#   🟢 训练完成: R²=0.9553, MAE=111.46, MAPE=12.53%
#   📊 训练过程图已保存: hw7result/plots\ENGINEERING_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 8/22] 训练学科: ENVIRONMENT ECOLOGY
#   📊 数据划分: 训练=1239 | 验证=413 | 测试=414
#   ⏹️ 提前停止于第 122 轮, 最佳验证损失: 8163.2402
#   🟢 训练完成: R²=0.9778, MAE=61.77, MAPE=10.54%
#   📊 训练过程图已保存: hw7result/plots\ENVIRONMENT_ECOLOGY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [ 9/22] 训练学科: GEOSCIENCES
#   📊 数据划分: 训练=705 | 验证=235 | 测试=235
#   ⏹️ 提前停止于第 183 轮, 最佳验证损失: 3550.3088
#   🟢 训练完成: R²=0.9573, MAE=45.65, MAPE=11.23%
#   📊 训练过程图已保存: hw7result/plots\GEOSCIENCES_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [10/22] 训练学科: IMMUNOLOGY
#   📊 数据划分: 训练=705 | 验证=236 | 测试=236
#   ⏹️ 提前停止于第 89 轮, 最佳验证损失: 2202.2114
#   🟢 训练完成: R²=0.9665, MAE=43.82, MAPE=8.99%
#   📊 训练过程图已保存: hw7result/plots\IMMUNOLOGY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [11/22] 训练学科: MATERIALS SCIENCE
#   📊 数据划分: 训练=948 | 验证=316 | 测试=316
#   ⏹️ 提前停止于第 121 轮, 最佳验证损失: 4349.0869
#   🟢 训练完成: R²=0.9883, MAE=35.72, MAPE=8.35%
#   📊 训练过程图已保存: hw7result/plots\MATERIALS_SCIENCE_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [12/22] 训练学科: MATHEMATICS
#   📊 数据划分: 训练=237 | 验证=79 | 测试=79
#   ⏹️ 提前停止于第 100 轮, 最佳验证损失: 1946.5701
#   🟢 训练完成: R²=0.9169, MAE=21.18, MAPE=17.36%
#   📊 训练过程图已保存: hw7result/plots\MATHEMATICS_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [13/22] 训练学科: MICROBIOLOGY
#   📊 数据划分: 训练=481 | 验证=161 | 测试=161
#   ⏹️ 提前停止于第 111 轮, 最佳验证损失: 3568.3381
#   🟢 训练完成: R²=0.9512, MAE=38.91, MAPE=20.78%
#   📊 训练过程图已保存: hw7result/plots\MICROBIOLOGY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [14/22] 训练学科: MOLECULAR BIOLOGY & GENETICS
#   📊 数据划分: 训练=701 | 验证=234 | 测试=234
#   ⏹️ 提前停止于第 104 轮, 最佳验证损失: 3370.8030
#   🟢 训练完成: R²=0.9829, MAE=32.68, MAPE=8.79%
#   📊 训练过程图已保存: hw7result/plots\MOLECULAR_BIOLOGY_&_GENETICS_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [15/22] 训练学科: MULTIDISCIPLINARY
#   📊 数据划分: 训练=129 | 验证=43 | 测试=44
#   🟢 训练完成: R²=0.9382, MAE=11.32, MAPE=11.51%
#   📊 训练过程图已保存: hw7result/plots\MULTIDISCIPLINARY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [16/22] 训练学科: NEUROSCIENCE & BEHAVIOR
#   📊 数据划分: 训练=778 | 验证=260 | 测试=260
#   ⏹️ 提前停止于第 122 轮, 最佳验证损失: 3458.6086
#   🟢 训练完成: R²=0.9643, MAE=45.22, MAPE=9.91%
#   📊 训练过程图已保存: hw7result/plots\NEUROSCIENCE_&_BEHAVIOR_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [17/22] 训练学科: PHARMACOLOGY & TOXICOLOGY
#   📊 数据划分: 训练=833 | 验证=278 | 测试=278
#   ⏹️ 提前停止于第 147 轮, 最佳验证损失: 6696.8545
#   🟢 训练完成: R²=0.9487, MAE=61.22, MAPE=13.93%
#   📊 训练过程图已保存: hw7result/plots\PHARMACOLOGY_&_TOXICOLOGY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [18/22] 训练学科: PHYSICS
#   📊 数据划分: 训练=597 | 验证=199 | 测试=199
#   ⏹️ 提前停止于第 106 轮, 最佳验证损失: 1916.9281
#   🟢 训练完成: R²=0.9758, MAE=33.24, MAPE=12.28%
#   📊 训练过程图已保存: hw7result/plots\PHYSICS_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [19/22] 训练学科: PLANT & ANIMAL SCIENCE
#   📊 数据划分: 训练=1170 | 验证=390 | 测试=390
#   ⏹️ 提前停止于第 179 轮, 最佳验证损失: 8183.0835
#   🟢 训练完成: R²=0.9703, MAE=71.58, MAPE=11.45%
#   📊 训练过程图已保存: hw7result/plots\PLANT_&_ANIMAL_SCIENCE_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [20/22] 训练学科: PSYCHIATRY PSYCHOLOGY
#   📊 数据划分: 训练=687 | 验证=230 | 测试=230
#   ⏹️ 提前停止于第 186 轮, 最佳验证损失: 2983.3335
#   🟢 训练完成: R²=0.9724, MAE=37.89, MAPE=9.32%
#   📊 训练过程图已保存: hw7result/plots\PSYCHIATRY_PSYCHOLOGY_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [21/22] 训练学科: SOCIAL SCIENCES, GENERAL
#   📊 数据划分: 训练=1443 | 验证=482 | 测试=482
#   ⏹️ 提前停止于第 111 轮, 最佳验证损失: 23195.7227
#   🟢 训练完成: R²=0.9514, MAE=103.69, MAPE=11.53%
#   📊 训练过程图已保存: hw7result/plots\SOCIAL_SCIENCES,_GENERAL_tabtransformer_training.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 🔬 [22/22] 训练学科: SPACE SCIENCE
#   📊 数据划分: 训练=141 | 验证=47 | 测试=48
#   ⏹️ 提前停止于第 133 轮, 最佳验证损失: 273.2622
#   🟢 训练完成: R²=0.9224, MAE=14.68, MAPE=17.81%
#   📊 训练过程图已保存: hw7result/plots\SPACE_SCIENCE_tabtransformer_training.png
# ================================================================================
# 📐 正在对评估指标进行归一化...
# ✅ 指标归一化完成
# ================================================================================
# 📈 TabTransformer 模型性能摘要报告
# ================================================================================
#
# 🏆 表现最佳的前5个学科 (按 composite_score 排序):
# ================================================================================
# 1. MATERIALS SCIENCE                   | R²: 0.9883 | MAE: 35.72 | 综合评分: 0.9659
# 2. MOLECULAR BIOLOGY & GENETICS        | R²: 0.9829 | MAE: 32.68 | 综合评分: 0.9378
# 3. PSYCHIATRY PSYCHOLOGY               | R²: 0.9724 | MAE: 37.89 | 综合评分: 0.8651
# 4. PHYSICS                             | R²: 0.9758 | MAE: 33.24 | 综合评分: 0.8647
# 5. ENVIRONMENT ECOLOGY                 | R²: 0.9778 | MAE: 61.77 | 综合评分: 0.8455
#
# ⚠️ 需要改进的后5个学科 (按 composite_score 排序):
# ================================================================================
# 1. ECONOMICS & BUSINESS                | R²: 0.9491 | MAE: 27.57 | 综合评分: 0.5990
# 2. COMPUTER SCIENCE                    | R²: 0.9368 | MAE: 45.83 | 综合评分: 0.5933
# 3. SPACE SCIENCE                       | R²: 0.9224 | MAE: 14.68 | 综合评分: 0.5296
# 4. MATHEMATICS                         | R²: 0.9169 | MAE: 21.18 | 综合评分: 0.5181
# 5. CLINICAL MEDICINE                   | R²: 0.9673 | MAE: 222.21 | 综合评分: 0.3794
#
# 💾 结果已保存到: hw7result\tabtransformer_metrics.csv
#
# ✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅ TabTransformer 训练完毕 ✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅✅

# %% [markdown]
# ## 模型性能统计分析
#
# 对所有学科的原始指标进行统计分析，包括均值、中位数、标准差等，以全面评估TabTransformer模型的整体表现。

# %%
# ============================================================================
# 📊 模型性能统计分析
# ============================================================================

def analyze_metrics_statistics(predictor):
    """
    对所有学科的原始指标进行统计分析
    
    Args:
        predictor: TabTransformerPredictor实例，包含所有训练结果
    
    Returns:
        stats_df: 包含所有指标统计信息的DataFrame
    """
    if not predictor.results:
        print("❌ 没有可用的训练结果进行统计分析")
        return None
    
    print("=" * 100)
    print("📊 TabTransformer 模型性能统计分析")
    print("=" * 100)
    
    # 收集所有指标数据
    metrics_data = {
        'MAE': [],
        'MSE': [],
        'RMSE': [],
        'R2': [],
        'MAPE': [],
        'Spearman': []
    }
    
    if HP.NORMALIZE_METRICS:
        metrics_data['Composite_Score'] = []
    
    for field, data in predictor.results.items():
        raw_metrics = data['raw_metrics']
        for metric_name in ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE', 'Spearman']:
            if metric_name in raw_metrics:
                metrics_data[metric_name].append(raw_metrics[metric_name])
        
        if HP.NORMALIZE_METRICS and 'composite_score' in data:
            metrics_data['Composite_Score'].append(data['composite_score'])
    
    # 计算统计量
    stats_results = []
    
    for metric_name, values in metrics_data.items():
        if not values:
            continue
        
        values_array = np.array(values)
        stats = {
            '指标': metric_name,
            '均值': np.mean(values_array),
            '中位数': np.median(values_array),
            '标准差': np.std(values_array),
            '最小值': np.min(values_array),
            '最大值': np.max(values_array),
            '25%分位': np.percentile(values_array, 25),
            '75%分位': np.percentile(values_array, 75),
            '样本数': len(values_array)
        }
        stats_results.append(stats)
    
    stats_df = pd.DataFrame(stats_results)
    
    # 打印统计表格
    print("\n📈 指标统计摘要:")
    print("-" * 100)
    print(stats_df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

    return stats_df

# 执行统计分析
if 'predictor' in locals():
    stats_df = analyze_metrics_statistics(predictor)
else:
    print("⚠️ 请先运行主程序训练模型，然后再执行统计分析")
    print("提示: 运行上面的单元格执行 main() 函数")
# Out:
# ====================================================================================================
# 📊 TabTransformer 模型性能统计分析
# ====================================================================================================
#
# 📈 指标统计摘要:
# ----------------------------------------------------------------------------------------------------
#              指标         均值       中位数        标准差      最小值         最大值     25%分位     75%分位  样本数
#             MAE    56.7880   45.4310    43.5425  11.3204    222.2100   33.8582   61.8342   22
#             MSE 11632.5766 4317.3646 25706.6217 213.7519 125490.7031 1978.1607 8274.8042   22
#            RMSE    82.6087   65.6663    69.3425  14.6203    354.2467   44.4492   90.9653   22
#              R2     0.9585    0.9608     0.0188   0.9169      0.9883    0.9488    0.9732   22
#            MAPE    13.1087   11.6037     3.9751   8.3506     24.4027   10.7137   14.3321   22
#        Spearman     0.9795    0.9815     0.0103   0.9558      0.9942    0.9713    0.9879   22
# Composite_Score     0.7161    0.7192     0.1474   0.3794      0.9659    0.6103    0.8366   22
